# %% [markdown]
# Numerical - > int, float, complex
# Text -> str (string)
# Sequence -> list, tuple, range
# Mapping : dict (key:value)
# set_type -> set
# Boolean type -> True, False

# %%
#Numberical
# integers --> int --> 1,2,3 (any number without deimals)
# float ---> decimal numbers
#Complex numbers ---> 10+20j

# %% [markdown]
# Whole number --> +ve or -ve, also without decimals

# %%
a = 100
type(a)
# Out:
# int

# %%
a = 100
print(type(a))
# Out:
# <class 'int'>

# %% [markdown]
# Float data type --> +ve or -ve, also with decimals

# %%
a = 10.20
print(type(a))
# Out:
# <class 'float'>

# %%
# addition
a = 10
b = 20
a+b
# Out:
# 30

# %%
100+65
# Out:
# 165

# %%
# Substraction
a = 10
b = 20
a-b
type(a-b)
# Out:
# int

# %%
# multiplication we denote by *
a = 10
b = 20
a*b
# Out:
# 200

# %%
# power we denote by **
a = 10
b = 20
a**b
# Out:
# 100000000000000000000

# %% [markdown]
# Complex Number : The number which is having real value and imaginary that number we called complex number

# %%
a = 3+20j
print(f'The value of a is {a} and data type of a is {type(a)}')
# Out:
# The value of a is (3+20j) and data type of a is <class 'complex'>

# %%
a = 3+20j

print(a)

print("a")
# Out:
# (3+20j)
# a

# %%
# / --> float output
a = 5
b = 24

b/a
# Out:
# 4.8

# %%
# // --> int output
a = 5
b = 24

b//a
# Out:
# 4

# %% [markdown]
# Conversion:
# 1. int --> float
# 2. float --> int
# 3. int --> complex
# 4. float --> complex
# 5. str --> int (only if value is base-10 value that is number)
# 6. int --> str

# %%
a = '5'
type(a)
# Out:
# str

# %%
print('I am string')
# Out:
# I am string

# %%
a = '33d'
# type(a)
b = int(a)
print(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-799020843.py in <cell line: 0>()
#       1 a = '33d'
#       2 # type(a)
# ----> 3 b = int(a)
#       4 print(b)
#
# ValueError: invalid literal for int() with base 10: '33d'

# %% [markdown]
# Float to int

# %%
a = 10.20
b = int(a)

print(b)
# Out:
# 10

# %%
a = 10.90
b = int(a)

print(b)
# Out:
# 10

# %% [markdown]
# int to float

# %%
a = 10 #10.0
b=float(a)
print(b)
# Out:
# 10.0

# %% [markdown]
# int  to complex

# %%
a = 100 #100+0j
b = complex(a)
print(b)
# Out:
# (100+0j)

# %%
a = 50.30
b= complex(a)
print(b)
# Out:
# (50.3+0j)

# %%
 #(5) is just an int. A tuple needs a comma: (5,).

# %%
var_check = (4)
type(var_check)
# Out:
# int

# %%
var_check = (4,5)
type(var_check)
# Out:
# tuple

# %% [markdown]
# float to complex
