# %% [markdown]
# if condition:
#   code (code can be of one line or 1000s or infinite lines)
#   statement1
# elif condition:
#   stetement2
# else:
#   statement3
#
# 1. Decision making statements
# 2. If statement cant be empty
# 3. If condition is true (satisfy), then the block of code will execute

# %% [markdown]
# #Comparison Operators
#
# 1. a == b --> equal operator
# 2. a != b --> not equal
# 3. a > b  --> Greater than
# 4. a < b  --> Less than
# 5. a >= b --> Greater than equal
# 6. a <= b --> Less than equal
#
# #Logical Operators
# 1. and:
#
# True and True --> True
# True and False --> False
# False and True --> False
# False and False --> False
# --> if both condition satisfy then only True else false
#
# 2. or
#
# True  or True --> True
# True  or False --> True
# False or True --> True
# False or False --> False
# --> if any condition is satisfying then it is True
#
# click --> alt + shift --> click end

# %%
a = 33
b = 45

if a < b :
    print("a is less than b")
    print("if condition executed")
else:
  print("a is not less than b")
  print("else condition executed")
# Out:
# a is less than b
# if condition executed

# %%
a = 33
b = 45

if a > b:
  print("a is less than b")
  print("if condition executed")
else:
  print("a is not less than b")
  print("else condition executed")
# Out:
# a is not less than b
# else condition executed

# %%
a = 63
b = 45

if a < b:
  print("a is less than b")
  print("if condition executed")
else:
  print("a is not less than b")
  print("else condition executed")
# Out:
# a is not less than b
# else condition executed

# %%
a = 45
b = 45

if a < b:
  print("a is less than b")
  print("if condition executed")
elif a == b:
  print("Both are equal")
else:
  print("a is not less than b")
  print("else condition executed")
# Out:
# last

# %%
a = 45
b = 45

if a < b:
  print("a is less than b")
  print("if condition executed")
elif a == b:
  print("Both are equal")
elif a > b:
    print("last elif block executed")
# Out:
# Both are equal

# %%
#To find the largest number
x = 10
y = 20
z = 30

if x>y and x>z:
  print("x is highest number and we are in if block")
elif y>x and y>z:
  print("y is highest number and we are in elif block")
elif z>x and z>y:
  print(f"{z} is highest number and we are in second elif block")
else:
  print("all are equal and we are in else block")
# Out:
# 30 is highest number and we are in second elif block

# %%
# in
# li = [1,2,3,4,5]

# if 3 in li

# %%
str_in = "python and data engineering"

if 'dataa' in str_in:
  print("data is present")
else:
  print("data is not present")
# Out:
# data is not present

# %%
str_in = "python and data engineering"

# input_variable = str(input("enter string element:"))
# input_variable = input("enter string element:")

inp_var = input("please enter string only:")

# input_variable = 'mitesh'
if input_variable in str_in:
  print("present")
else:
  print("not present")
# Out:
# please enter string only: Depak
# not present

# %%
# we can use only if block as well but we cant use else or elif block without if block.
age = 20
if age>18:
  print("you are eligible for vote")
# Out:
# you are eligible for vote

# %%
if False:
  pass
else:
  print("else")
# Out:
# else

# %%
#Student grading system
# grade A = 90
# grade B = 76-89
# grade C = 75 equeal or less
# Fail = less than 50
score = int(input("Enter the score:"))

if score >= 90:
  if score >= 75:
    if score >= 90:
      print("grade A")
    else:
      print("Grade B")
  else:
    print("Grade C")
else:
  print("Fail")
# Out:
# Enter the score:47
# Fail

# %%
# ATM Withdrawal example. include withdrawal limit as 20000
balance = 5000
withdrawal = 2000
pin_correct = True

# %% [markdown]
# pin --> withdr amont --> limit

# %%
if pin_correct:
  #now it will check if balance is greater than withdrawal amount
  if withdrawal <= balance:
    #now it will check withdrawal amount is less than limit of ATM
    if withdrawal <= 10000:
      print("Transanction successfuly")
    else:
      print("Transanction exceed limit")

# %%
if pin_correct:
  if withdrawal <= balance:
    if withdrawal <= 10000:
      print("Transanction successfuly")
    else:
      print("Transanction exceed limit")
  else:
    print("Insufficient balance")
else:
  print("invalid pin")

# %% [markdown]
# Nested if-else
